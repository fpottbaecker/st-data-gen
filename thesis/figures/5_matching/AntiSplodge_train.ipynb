# %% [markdown]
# ### AntiSplodge Reference Training
# After generating all of the dataset variants, this notebook is used to train AntiSplodge for the reference datasets.
#
# This is based on the [miminal AntiSplodge example](https://github.com/HealthML/AntiSplodge/blob/52e71a1e40b4161926ebbe45f8e18fc02de69bdc/AntiSplodge_minimal_example.ipynb) provided by the authors.

# %%
import anndata as ann
import scanpy as sc
import numpy as np
import pickle

import antisplodge as AS

from collections import Counter

# %% [markdown]
# After importing the required packages, load the dataset into memory, remember to have the dataset in the same folder as the notebook.

# %%
REFERENCE_PATH = f"../../data/reference"
REFERENCE_DATASETS = {
    "Harvard_gender_female_full": f"{REFERENCE_PATH}/hca_harvard_gender_Female.sc.h5ad",
    "Harvard_gender_female_V1": f"{REFERENCE_PATH}/hca_harvard_gender_Female_-muscles.sc.h5ad",
    "Harvard_gender_female_V2": f"{REFERENCE_PATH}/hca_harvard_gender_Female_-endothelial.sc.h5ad",
    "Sanger_gender_female_full": f"{REFERENCE_PATH}/hca_sanger_gender_Female.sc.h5ad",
    "Sanger_gender_female_V1": f"{REFERENCE_PATH}/hca_sanger_gender_Female_-muscles.sc.h5ad",
    "Sanger_gender_female_V2": f"{REFERENCE_PATH}/hca_sanger_gender_Female_-endothelial.sc.h5ad",
}

datasets = {}

for name, path in REFERENCE_DATASETS.items():
    datasets[name] = ann.read(path)

# %%
for dat, dataset in datasets.items():
    print(dat, dataset.shape)
# Out:
# Harvard_gender_female_full (44898, 33538)
# Harvard_gender_female_V1 (21169, 33538)
# Harvard_gender_female_V2 (41957, 33538)
# Sanger_gender_female_full (36966, 33538)
# Sanger_gender_female_V1 (20159, 33538)
# Sanger_gender_female_V2 (34174, 33538)

# %% [markdown]
# ### Find marker genes
# Because of the high number of genes (N=33538), we want to reduce the set of genes to a smaller one in order to speed up training and reduce memory footprint. But it would work with all the genes, but the time to get an as good model will be a lot higher.
#
# However, before we look for marker genes, we scale all profiles to 1 using scanpy's function normalize_total, as shown below:

# %%
for dataset in datasets.values():
    sc.pp.normalize_total(dataset, target_sum=1)

# %%
#
# Find the top 'key' marker genes that was found for each cell type during the univariate t-test analysis 
#
# usually you should use method='logreg', but t-test is faster for demonstration purpose
for dataset in datasets.values():
    sc.tl.rank_genes_groups(dataset, groupby='cell_type', method='t-test', use_raw=False, key_added='ranks')

# %%
#
# Get the corresponding gene sets
#
def getGenes(adata, key, ct, min_genes, score_threshold=0.01):
    genes = []
    
    # get the N most correlated genes for each cell type
    for i, cell_ in enumerate(ct):
        
        # find the number of genes to include
        index = min_genes 
        while adata.uns[key]['scores'][cell_][index] > score_threshold: # hardcoded 0.01 inclusion 
            index += 1
        
        genes_ = adata.uns[key]['names'][cell_][0:index]
        scores = adata.uns[key]['scores'][cell_][0:index]
        
        print(cell_, len(genes_))
        
        genes.extend(genes_)
        
    np_genes = np.unique(np.array(genes))
    print("Length of unique genes:",len(np_genes))
    
    return np_genes

# use the top 50 for cell_type and allow some threshold to select the rest, 
# only ventricular cardiomyocytes have genes with scores above this threshold
gene_sets = {}
for dat, dataset in datasets.items():
    gene_sets[dat] = getGenes(dataset, 'ranks', np.unique(dataset.obs['cell_type']), 50, 50)
# Out:
# Adipocytes 50
# Atrial_Cardiomyocyte 50
# Endothelial 50
# Fibroblast 50
# Lymphoid 50
# Myeloid 50
# Neuronal 50
# Pericytes 76
# Smooth_muscle_cells 50
# Ventricular_Cardiomyocyte 344
# Length of unique genes: 736
# Adipocytes 50
# Endothelial 50
# Fibroblast 50
# Lymphoid 50
# Myeloid 50
# Neuronal 50
# Pericytes 50
# Smooth_muscle_cells 50
# Length of unique genes: 378
# Adipocytes 50
# Atrial_Cardiomyocyte 50
# Fibroblast 50
# Lymphoid 50
# Myeloid 50
# Neuronal 50
# Pericytes 81
# Smooth_muscle_cells 50
# Ventricular_Cardiomyocyte 334
# Length of unique genes: 698
# Adipocytes 50
# Atrial_Cardiomyocyte 50
# Endothelial 50
# Fibroblast 50
# Lymphoid 50
# Mesothelial 50
# Myeloid 50
# Neuronal 50
# Pericytes 50
# Smooth_muscle_cells 50
# Ventricular_Cardiomyocyte 250
# Length of unique genes: 670
# Adipocytes 50
# Endothelial 50
# Fibroblast 50
# Lymphoid 50
# Mesothelial 50
# Myeloid 50
# Neuronal 50
# Pericytes 50
# Smooth_muscle_cells 50
# Length of unique genes: 416
# Adipocytes 50
# Atrial_Cardiomyocyte 50
# Fibroblast 50
# Lymphoid 50
# Mesothelial 50
# Myeloid 50
# Neuronal 50
# Pericytes 50
# Smooth_muscle_cells 50
# Ventricular_Cardiomyocyte 244
# Length of unique genes: 628

# %%
for dat in list(datasets.keys()):
    datasets[dat] = datasets[dat][:,gene_sets[dat]] # filter SC

# %% [markdown]
# We need to scale again after removing unwanted genes, in order to again, have profiles of equal counts!

# %%
for dataset in datasets.values():
    sc.pp.normalize_total(dataset, target_sum=1)
# Out:
# /dhc/home/fabian.pottbaecker/conda3/envs/workspace/lib/python3.10/site-packages/scanpy/preprocessing/_normalization.py:170: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
# the profiles are now much smaller which will reduce memory and speed up traininig time
for dat, dataset in datasets.items():
    print(dat, dataset.shape)
# Out:
# Harvard_gender_female_full (44898, 736)
# Harvard_gender_female_V1 (21169, 378)
# Harvard_gender_female_V2 (41957, 698)
# Sanger_gender_female_full (36966, 670)
# Sanger_gender_female_V1 (20159, 416)
# Sanger_gender_female_V2 (34174, 628)

# %% [markdown]
# ### AntiSplodge experiment
# We then setup the AntiSplodge experiment, in this step we do:
#
# 1) Create a new experiment by passing SC to the AntiSplodge 'DeconvolutionExperiment' function.
# 2) We set the cell type column to 'cell_type' in the dataset
# 3) We split the dataset into 80% train, 10% validation, and, 10% test.

# %%
experiments = {}

for dat, dataset in datasets.items():
    experiment = AS.DeconvolutionExperiment(dataset)
    experiment.setVerbosity(True)

    # CELLTYPE_COLUMN should be replaced with actual column
    experiment.setCellTypeColumn('cell_type')
    # Use 80% as train data and split the rest into a 50/50 split validation and testing
    experiment.splitTrainTestValidation(train=0.8, rest=0.5)
    experiments[dat] = experiment

# %% [markdown]
# Then we generate 500.000 training, 10.000 validation, and, 10.000 test samples.
# And load these into data loaders for use in training of the neural network.

# %%
for experiment in experiments.values():
    experiment.generateTrainTestValidation(num_profiles=[500000,10000,10000], CD=[10,10])
    # Load the profiles into data loaders
    experiment.setupDataLoaders(batch_size=2500)
# Out:
# GENERATING PROFILES
# GENERATING TRAIN DATASET (N=500000)
# GENERATING VALIDATION DATASET (N=10000)
# GENERATING TEST DATASET (N=10000)
# GENERATING PROFILES
# GENERATING TRAIN DATASET (N=500000)
# GENERATING VALIDATION DATASET (N=10000)
# GENERATING TEST DATASET (N=10000)
# GENERATING PROFILES
# GENERATING TRAIN DATASET (N=500000)
# GENERATING VALIDATION DATASET (N=10000)
# GENERATING TEST DATASET (N=10000)
# GENERATING PROFILES
# GENERATING TRAIN DATASET (N=500000)
# GENERATING VALIDATION DATASET (N=10000)
# GENERATING TEST DATASET (N=10000)
# GENERATING PROFILES
# GENERATING TRAIN DATASET (N=500000)
# GENERATING VALIDATION DATASET (N=10000)
# GENERATING TEST DATASET (N=10000)
# GENERATING PROFILES
# GENERATING TRAIN DATASET (N=500000)
# GENERATING VALIDATION DATASET (N=10000)
# GENERATING TEST DATASET (N=10000)

# %% [markdown]
# We then define the model (with default values) and use the first cuda device (cuda_id=1).

# %%
# Initialize Neural network-model and allocate it to the cuda_id specified
# Use 'cuda_id="cpu"' if you want to allocate it to a cpu
for experiment in experiments.values():
    experiment.setupModel(cuda_id=0)
# Out:
# (CUDA) device is: cuda:0
# (CUDA) device is: cuda:0
# (CUDA) device is: cuda:0
# (CUDA) device is: cuda:0
# (CUDA) device is: cuda:0
# (CUDA) device is: cuda:0

# %% [markdown]
# We then train the network with 25 warm restarts, this means whenever we finish a training session we load the best model settings we have found so far back onto the model and continue from there in the next setting.

# %%
for dat, experiment in experiments.items():
    # do 25 warm restarts with decreasing learning rate
    print("Training experiment for dataset")
    experiment.setVerbosity(False)
    lr = 0.001
    best_error=None # no target error to beat in the beginning
    for k in range(25):

        # Consider changing learning rate (lr) during run more dynamically
        if k >= 5:
            lr = 0.0005
        if k >= 10:
            lr = 0.0001
        if k >= 15:
            lr = 0.00005
        experiment.setupOptimizerAndCriterion(learning_rate = lr)
        # Train the experiment constructed by passing the experiment to the AntiSplodge training function
        AS.train(experiment, save_file=f"{dat}.model.pt", patience=5, best_loss=best_error) # For longer training, increase patience threshold
        best_error = AS.getMeanJSD(experiment, "validation") # set best error as the target error to beat

        print("Restart [{}] - JSDs".format(k), AS.getMeanJSD(experiment, "validation"))
    experiment.setVerbosity(True)
# Out:
# Training experiment for dataset
# Finished training (checkpoint saved in: Harvard_gender_female_full.model.pt)
# Time elapsed: 62.10 (1.03 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_full.model.pt
# Restart [0] - JSDs 0.11716707077861588
# Finished training (checkpoint saved in: Harvard_gender_female_full.model.pt)
# Time elapsed: 55.64 (0.93 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_full.model.pt
# Restart [1] - JSDs 0.11581717265608009
# Finished training (checkpoint saved in: Harvard_gender_female_full.model.pt)
# Time elapsed: 37.35 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_full.model.pt
# Restart [2] - JSDs 0.11581717265608009
# Finished training (checkpoint saved in: Harvard_gender_female_full.model.pt)
# Time elapsed: 37.14 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_full.model.pt
# Restart [3] - JSDs 0.1147938126292634
# Finished training (checkpoint saved in: Harvard_gender_female_full.model.pt)
# Time elapsed: 62.13 (1.04 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_full.model.pt
# Restart [4] - JSDs 0.11326721009876578
# Finished training (checkpoint saved in: Harvard_gender_female_full.model.pt)
# Time elapsed: 93.51 (1.56 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_full.model.pt
# Restart [5] - JSDs 0.11178580554638563
# Finished training (checkpoint saved in: Harvard_gender_female_full.model.pt)
# Time elapsed: 37.39 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_full.model.pt
# Restart [6] - JSDs 0.11178580554638563
# Finished training (checkpoint saved in: Harvard_gender_female_full.model.pt)
# Time elapsed: 56.06 (0.93 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_full.model.pt
# Restart [7] - JSDs 0.1112085066307931
# Finished training (checkpoint saved in: Harvard_gender_female_full.model.pt)
# Time elapsed: 37.34 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_full.model.pt
# Restart [8] - JSDs 0.1112085066307931
# Finished training (checkpoint saved in: Harvard_gender_female_full.model.pt)
# Time elapsed: 37.65 (0.63 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_full.model.pt
# Restart [9] - JSDs 0.11044929009705688
# Finished training (checkpoint saved in: Harvard_gender_female_full.model.pt)
# Time elapsed: 37.36 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_full.model.pt
# Restart [10] - JSDs 0.11044929009705688
# Finished training (checkpoint saved in: Harvard_gender_female_full.model.pt)
# Time elapsed: 37.36 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_full.model.pt
# Restart [11] - JSDs 0.11044929009705688
# Finished training (checkpoint saved in: Harvard_gender_female_full.model.pt)
# Time elapsed: 37.36 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_full.model.pt
# Restart [12] - JSDs 0.11044929009705688
# Finished training (checkpoint saved in: Harvard_gender_female_full.model.pt)
# Time elapsed: 37.38 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_full.model.pt
# Restart [13] - JSDs 0.11044929009705688
# Finished training (checkpoint saved in: Harvard_gender_female_full.model.pt)
# Time elapsed: 43.72 (0.73 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_full.model.pt
# Restart [14] - JSDs 0.11042573445610761
# Finished training (checkpoint saved in: Harvard_gender_female_full.model.pt)
# Time elapsed: 37.39 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_full.model.pt
# Restart [15] - JSDs 0.11042573445610761
# Finished training (checkpoint saved in: Harvard_gender_female_full.model.pt)
# Time elapsed: 37.64 (0.63 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_full.model.pt
# Restart [16] - JSDs 0.11042573445610761
# Finished training (checkpoint saved in: Harvard_gender_female_full.model.pt)
# Time elapsed: 37.40 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_full.model.pt
# Restart [17] - JSDs 0.11042573445610761
# Finished training (checkpoint saved in: Harvard_gender_female_full.model.pt)
# Time elapsed: 37.37 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_full.model.pt
# Restart [18] - JSDs 0.11042573445610761
# Finished training (checkpoint saved in: Harvard_gender_female_full.model.pt)
# Time elapsed: 37.36 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_full.model.pt
# Restart [19] - JSDs 0.11042573445610761
# Finished training (checkpoint saved in: Harvard_gender_female_full.model.pt)
# Time elapsed: 37.37 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_full.model.pt
# Restart [20] - JSDs 0.11042573445610761
# Finished training (checkpoint saved in: Harvard_gender_female_full.model.pt)
# Time elapsed: 37.33 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_full.model.pt
# Restart [21] - JSDs 0.11042573445610761
# Finished training (checkpoint saved in: Harvard_gender_female_full.model.pt)
# Time elapsed: 37.38 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_full.model.pt
# Restart [22] - JSDs 0.11042573445610761
# Finished training (checkpoint saved in: Harvard_gender_female_full.model.pt)
# Time elapsed: 37.37 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_full.model.pt
# Restart [23] - JSDs 0.11042573445610761
# Finished training (checkpoint saved in: Harvard_gender_female_full.model.pt)
# Time elapsed: 37.63 (0.63 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_full.model.pt
# Restart [24] - JSDs 0.11042573445610761
# Training experiment for dataset
# Finished training (checkpoint saved in: Harvard_gender_female_V1.model.pt)
# Time elapsed: 102.91 (1.72 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V1.model.pt
# Restart [0] - JSDs 0.10926389222483901
# Finished training (checkpoint saved in: Harvard_gender_female_V1.model.pt)
# Time elapsed: 36.26 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V1.model.pt
# Restart [1] - JSDs 0.10904721297562492
# Finished training (checkpoint saved in: Harvard_gender_female_V1.model.pt)
# Time elapsed: 36.23 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V1.model.pt
# Restart [2] - JSDs 0.10904721297562492
# Finished training (checkpoint saved in: Harvard_gender_female_V1.model.pt)
# Time elapsed: 36.25 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V1.model.pt
# Restart [3] - JSDs 0.10904721297562492
# Finished training (checkpoint saved in: Harvard_gender_female_V1.model.pt)
# Time elapsed: 36.24 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V1.model.pt
# Restart [4] - JSDs 0.10904721297562492
# Finished training (checkpoint saved in: Harvard_gender_female_V1.model.pt)
# Time elapsed: 36.36 (0.61 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V1.model.pt
# Restart [5] - JSDs 0.10904721297562492
# Finished training (checkpoint saved in: Harvard_gender_female_V1.model.pt)
# Time elapsed: 72.66 (1.21 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V1.model.pt
# Restart [6] - JSDs 0.10735448478841711
# Finished training (checkpoint saved in: Harvard_gender_female_V1.model.pt)
# Time elapsed: 84.87 (1.41 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V1.model.pt
# Restart [7] - JSDs 0.10595262267503401
# Finished training (checkpoint saved in: Harvard_gender_female_V1.model.pt)
# Time elapsed: 36.23 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V1.model.pt
# Restart [8] - JSDs 0.10595262267503401
# Finished training (checkpoint saved in: Harvard_gender_female_V1.model.pt)
# Time elapsed: 36.16 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V1.model.pt
# Restart [9] - JSDs 0.10595262267503401
# Finished training (checkpoint saved in: Harvard_gender_female_V1.model.pt)
# Time elapsed: 66.42 (1.11 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V1.model.pt
# Restart [10] - JSDs 0.10419672210148916
# Finished training (checkpoint saved in: Harvard_gender_female_V1.model.pt)
# Time elapsed: 78.77 (1.31 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V1.model.pt
# Restart [11] - JSDs 0.1038647014824217
# Finished training (checkpoint saved in: Harvard_gender_female_V1.model.pt)
# Time elapsed: 36.21 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V1.model.pt
# Restart [12] - JSDs 0.1038647014824217
# Finished training (checkpoint saved in: Harvard_gender_female_V1.model.pt)
# Time elapsed: 36.21 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V1.model.pt
# Restart [13] - JSDs 0.1038647014824217
# Finished training (checkpoint saved in: Harvard_gender_female_V1.model.pt)
# Time elapsed: 36.28 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V1.model.pt
# Restart [14] - JSDs 0.1038647014824217
# Finished training (checkpoint saved in: Harvard_gender_female_V1.model.pt)
# Time elapsed: 36.21 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V1.model.pt
# Restart [15] - JSDs 0.1038647014824217
# Finished training (checkpoint saved in: Harvard_gender_female_V1.model.pt)
# Time elapsed: 54.36 (0.91 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V1.model.pt
# Restart [16] - JSDs 0.10371500979723194
# Finished training (checkpoint saved in: Harvard_gender_female_V1.model.pt)
# Time elapsed: 36.49 (0.61 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V1.model.pt
# Restart [17] - JSDs 0.10371500979723194
# Finished training (checkpoint saved in: Harvard_gender_female_V1.model.pt)
# Time elapsed: 36.23 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V1.model.pt
# Restart [18] - JSDs 0.10371500979723194
# Finished training (checkpoint saved in: Harvard_gender_female_V1.model.pt)
# Time elapsed: 36.20 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V1.model.pt
# Restart [19] - JSDs 0.10371500979723194
# Finished training (checkpoint saved in: Harvard_gender_female_V1.model.pt)
# Time elapsed: 36.18 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V1.model.pt
# Restart [20] - JSDs 0.10371500979723194
# Finished training (checkpoint saved in: Harvard_gender_female_V1.model.pt)
# Time elapsed: 36.22 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V1.model.pt
# Restart [21] - JSDs 0.10371500979723194
# Finished training (checkpoint saved in: Harvard_gender_female_V1.model.pt)
# Time elapsed: 36.23 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V1.model.pt
# Restart [22] - JSDs 0.10371500979723194
# Finished training (checkpoint saved in: Harvard_gender_female_V1.model.pt)
# Time elapsed: 36.19 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V1.model.pt
# Restart [23] - JSDs 0.10371500979723194
# Finished training (checkpoint saved in: Harvard_gender_female_V1.model.pt)
# Time elapsed: 36.14 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V1.model.pt
# Restart [24] - JSDs 0.10371500979723194
# Training experiment for dataset
# Finished training (checkpoint saved in: Harvard_gender_female_V2.model.pt)
# Time elapsed: 118.67 (1.98 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V2.model.pt
# Restart [0] - JSDs 0.09504453142551587
# Finished training (checkpoint saved in: Harvard_gender_female_V2.model.pt)
# Time elapsed: 37.49 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V2.model.pt
# Restart [1] - JSDs 0.09504453142551587
# Finished training (checkpoint saved in: Harvard_gender_female_V2.model.pt)
# Time elapsed: 68.64 (1.14 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V2.model.pt
# Restart [2] - JSDs 0.09244579859993543
# Finished training (checkpoint saved in: Harvard_gender_female_V2.model.pt)
# Time elapsed: 37.50 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V2.model.pt
# Restart [3] - JSDs 0.09244579859993543
# Finished training (checkpoint saved in: Harvard_gender_female_V2.model.pt)
# Time elapsed: 75.25 (1.25 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V2.model.pt
# Restart [4] - JSDs 0.09208136571555917
# Finished training (checkpoint saved in: Harvard_gender_female_V2.model.pt)
# Time elapsed: 37.48 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V2.model.pt
# Restart [5] - JSDs 0.09139410300559976
# Finished training (checkpoint saved in: Harvard_gender_female_V2.model.pt)
# Time elapsed: 62.26 (1.04 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V2.model.pt
# Restart [6] - JSDs 0.08971620058918797
# Finished training (checkpoint saved in: Harvard_gender_female_V2.model.pt)
# Time elapsed: 37.49 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V2.model.pt
# Restart [7] - JSDs 0.08971620058918797
# Finished training (checkpoint saved in: Harvard_gender_female_V2.model.pt)
# Time elapsed: 37.13 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V2.model.pt
# Restart [8] - JSDs 0.08971620058918797
# Finished training (checkpoint saved in: Harvard_gender_female_V2.model.pt)
# Time elapsed: 62.19 (1.04 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V2.model.pt
# Restart [9] - JSDs 0.08856809170527313
# Finished training (checkpoint saved in: Harvard_gender_female_V2.model.pt)
# Time elapsed: 37.71 (0.63 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V2.model.pt
# Restart [10] - JSDs 0.08835416078452586
# Finished training (checkpoint saved in: Harvard_gender_female_V2.model.pt)
# Time elapsed: 37.16 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V2.model.pt
# Restart [11] - JSDs 0.08835416078452586
# Finished training (checkpoint saved in: Harvard_gender_female_V2.model.pt)
# Time elapsed: 37.43 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V2.model.pt
# Restart [12] - JSDs 0.08835416078452586
# Finished training (checkpoint saved in: Harvard_gender_female_V2.model.pt)
# Time elapsed: 37.44 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V2.model.pt
# Restart [13] - JSDs 0.08835416078452586
# Finished training (checkpoint saved in: Harvard_gender_female_V2.model.pt)
# Time elapsed: 37.47 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V2.model.pt
# Restart [14] - JSDs 0.08835416078452586
# Finished training (checkpoint saved in: Harvard_gender_female_V2.model.pt)
# Time elapsed: 62.56 (1.04 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V2.model.pt
# Restart [15] - JSDs 0.08824626783116515
# Finished training (checkpoint saved in: Harvard_gender_female_V2.model.pt)
# Time elapsed: 37.50 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V2.model.pt
# Restart [16] - JSDs 0.08824626783116515
# Finished training (checkpoint saved in: Harvard_gender_female_V2.model.pt)
# Time elapsed: 37.56 (0.63 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V2.model.pt
# Restart [17] - JSDs 0.08824626783116515
# Finished training (checkpoint saved in: Harvard_gender_female_V2.model.pt)
# Time elapsed: 69.15 (1.15 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V2.model.pt
# Restart [18] - JSDs 0.08801851455705928
# Finished training (checkpoint saved in: Harvard_gender_female_V2.model.pt)
# Time elapsed: 50.34 (0.84 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V2.model.pt
# Restart [19] - JSDs 0.08799973754849826
# Finished training (checkpoint saved in: Harvard_gender_female_V2.model.pt)
# Time elapsed: 37.47 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V2.model.pt
# Restart [20] - JSDs 0.08799973754849826
# Finished training (checkpoint saved in: Harvard_gender_female_V2.model.pt)
# Time elapsed: 62.61 (1.04 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V2.model.pt
# Restart [21] - JSDs 0.08797227084115994
# Finished training (checkpoint saved in: Harvard_gender_female_V2.model.pt)
# Time elapsed: 37.50 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V2.model.pt
# Restart [22] - JSDs 0.08797227084115994
# Finished training (checkpoint saved in: Harvard_gender_female_V2.model.pt)
# Time elapsed: 56.50 (0.94 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V2.model.pt
# Restart [23] - JSDs 0.08772659321717954
# Finished training (checkpoint saved in: Harvard_gender_female_V2.model.pt)
# Time elapsed: 37.47 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Harvard_gender_female_V2.model.pt
# Restart [24] - JSDs 0.08772659321717954
# Training experiment for dataset
# Finished training (checkpoint saved in: Sanger_gender_female_full.model.pt)
# Time elapsed: 93.56 (1.56 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_full.model.pt
# Restart [0] - JSDs 0.14805035199293376
# Finished training (checkpoint saved in: Sanger_gender_female_full.model.pt)
# Time elapsed: 37.41 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_full.model.pt
# Restart [1] - JSDs 0.14805035199293376
# Finished training (checkpoint saved in: Sanger_gender_female_full.model.pt)
# Time elapsed: 37.40 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_full.model.pt
# Restart [2] - JSDs 0.14805035199293376
# Finished training (checkpoint saved in: Sanger_gender_female_full.model.pt)
# Time elapsed: 62.09 (1.03 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_full.model.pt
# Restart [3] - JSDs 0.1452003137311631
# Finished training (checkpoint saved in: Sanger_gender_female_full.model.pt)
# Time elapsed: 37.68 (0.63 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_full.model.pt
# Restart [4] - JSDs 0.1452003137311631
# Finished training (checkpoint saved in: Sanger_gender_female_full.model.pt)
# Time elapsed: 74.53 (1.24 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_full.model.pt
# Restart [5] - JSDs 0.13746406247806414
# Finished training (checkpoint saved in: Sanger_gender_female_full.model.pt)
# Time elapsed: 37.36 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_full.model.pt
# Restart [6] - JSDs 0.13746406247806414
# Finished training (checkpoint saved in: Sanger_gender_female_full.model.pt)
# Time elapsed: 37.39 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_full.model.pt
# Restart [7] - JSDs 0.13746406247806414
# Finished training (checkpoint saved in: Sanger_gender_female_full.model.pt)
# Time elapsed: 37.40 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_full.model.pt
# Restart [8] - JSDs 0.13746406247806414
# Finished training (checkpoint saved in: Sanger_gender_female_full.model.pt)
# Time elapsed: 37.36 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_full.model.pt
# Restart [9] - JSDs 0.13746406247806414
# Finished training (checkpoint saved in: Sanger_gender_female_full.model.pt)
# Time elapsed: 62.35 (1.04 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_full.model.pt
# Restart [10] - JSDs 0.13735782284939496
# Finished training (checkpoint saved in: Sanger_gender_female_full.model.pt)
# Time elapsed: 37.38 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_full.model.pt
# Restart [11] - JSDs 0.13735782284939496
# Finished training (checkpoint saved in: Sanger_gender_female_full.model.pt)
# Time elapsed: 37.03 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_full.model.pt
# Restart [12] - JSDs 0.13735782284939496
# Finished training (checkpoint saved in: Sanger_gender_female_full.model.pt)
# Time elapsed: 37.38 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_full.model.pt
# Restart [13] - JSDs 0.13735782284939496
# Finished training (checkpoint saved in: Sanger_gender_female_full.model.pt)
# Time elapsed: 37.34 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_full.model.pt
# Restart [14] - JSDs 0.13735782284939496
# Finished training (checkpoint saved in: Sanger_gender_female_full.model.pt)
# Time elapsed: 37.40 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_full.model.pt
# Restart [15] - JSDs 0.13735782284939496
# Finished training (checkpoint saved in: Sanger_gender_female_full.model.pt)
# Time elapsed: 37.33 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_full.model.pt
# Restart [16] - JSDs 0.13735782284939496
# Finished training (checkpoint saved in: Sanger_gender_female_full.model.pt)
# Time elapsed: 37.38 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_full.model.pt
# Restart [17] - JSDs 0.13735782284939496
# Finished training (checkpoint saved in: Sanger_gender_female_full.model.pt)
# Time elapsed: 37.66 (0.63 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_full.model.pt
# Restart [18] - JSDs 0.13735782284939496
# Finished training (checkpoint saved in: Sanger_gender_female_full.model.pt)
# Time elapsed: 37.35 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_full.model.pt
# Restart [19] - JSDs 0.13735782284939496
# Finished training (checkpoint saved in: Sanger_gender_female_full.model.pt)
# Time elapsed: 37.35 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_full.model.pt
# Restart [20] - JSDs 0.13735782284939496
# Finished training (checkpoint saved in: Sanger_gender_female_full.model.pt)
# Time elapsed: 37.36 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_full.model.pt
# Restart [21] - JSDs 0.13735782284939496
# Finished training (checkpoint saved in: Sanger_gender_female_full.model.pt)
# Time elapsed: 37.36 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_full.model.pt
# Restart [22] - JSDs 0.13735782284939496
# Finished training (checkpoint saved in: Sanger_gender_female_full.model.pt)
# Time elapsed: 37.36 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_full.model.pt
# Restart [23] - JSDs 0.13735782284939496
# Finished training (checkpoint saved in: Sanger_gender_female_full.model.pt)
# Time elapsed: 37.38 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_full.model.pt
# Restart [24] - JSDs 0.13735782284939496
# Training experiment for dataset
# Finished training (checkpoint saved in: Sanger_gender_female_V1.model.pt)
# Time elapsed: 96.79 (1.61 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V1.model.pt
# Restart [0] - JSDs 0.1317706075142866
# Finished training (checkpoint saved in: Sanger_gender_female_V1.model.pt)
# Time elapsed: 65.87 (1.10 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V1.model.pt
# Restart [1] - JSDs 0.129133005874016
# Finished training (checkpoint saved in: Sanger_gender_female_V1.model.pt)
# Time elapsed: 35.84 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V1.model.pt
# Restart [2] - JSDs 0.129133005874016
# Finished training (checkpoint saved in: Sanger_gender_female_V1.model.pt)
# Time elapsed: 72.18 (1.20 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V1.model.pt
# Restart [3] - JSDs 0.12397061606884258
# Finished training (checkpoint saved in: Sanger_gender_female_V1.model.pt)
# Time elapsed: 36.19 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V1.model.pt
# Restart [4] - JSDs 0.12397061606884258
# Finished training (checkpoint saved in: Sanger_gender_female_V1.model.pt)
# Time elapsed: 36.43 (0.61 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V1.model.pt
# Restart [5] - JSDs 0.12296053485987027
# Finished training (checkpoint saved in: Sanger_gender_female_V1.model.pt)
# Time elapsed: 36.34 (0.61 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V1.model.pt
# Restart [6] - JSDs 0.12296053485987027
# Finished training (checkpoint saved in: Sanger_gender_female_V1.model.pt)
# Time elapsed: 36.23 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V1.model.pt
# Restart [7] - JSDs 0.12296053485987027
# Finished training (checkpoint saved in: Sanger_gender_female_V1.model.pt)
# Time elapsed: 48.30 (0.80 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V1.model.pt
# Restart [8] - JSDs 0.12288951464345468
# Finished training (checkpoint saved in: Sanger_gender_female_V1.model.pt)
# Time elapsed: 36.22 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V1.model.pt
# Restart [9] - JSDs 0.12288951464345468
# Finished training (checkpoint saved in: Sanger_gender_female_V1.model.pt)
# Time elapsed: 84.09 (1.40 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V1.model.pt
# Restart [10] - JSDs 0.1222608041421713
# Finished training (checkpoint saved in: Sanger_gender_female_V1.model.pt)
# Time elapsed: 36.24 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V1.model.pt
# Restart [11] - JSDs 0.1222608041421713
# Finished training (checkpoint saved in: Sanger_gender_female_V1.model.pt)
# Time elapsed: 36.54 (0.61 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V1.model.pt
# Restart [12] - JSDs 0.1222608041421713
# Finished training (checkpoint saved in: Sanger_gender_female_V1.model.pt)
# Time elapsed: 36.22 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V1.model.pt
# Restart [13] - JSDs 0.1222608041421713
# Finished training (checkpoint saved in: Sanger_gender_female_V1.model.pt)
# Time elapsed: 36.19 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V1.model.pt
# Restart [14] - JSDs 0.1222608041421713
# Finished training (checkpoint saved in: Sanger_gender_female_V1.model.pt)
# Time elapsed: 36.21 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V1.model.pt
# Restart [15] - JSDs 0.1222608041421713
# Finished training (checkpoint saved in: Sanger_gender_female_V1.model.pt)
# Time elapsed: 84.06 (1.40 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V1.model.pt
# Restart [16] - JSDs 0.121926599131718
# Finished training (checkpoint saved in: Sanger_gender_female_V1.model.pt)
# Time elapsed: 35.81 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V1.model.pt
# Restart [17] - JSDs 0.121926599131718
# Finished training (checkpoint saved in: Sanger_gender_female_V1.model.pt)
# Time elapsed: 35.82 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V1.model.pt
# Restart [18] - JSDs 0.121926599131718
# Finished training (checkpoint saved in: Sanger_gender_female_V1.model.pt)
# Time elapsed: 36.22 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V1.model.pt
# Restart [19] - JSDs 0.121926599131718
# Finished training (checkpoint saved in: Sanger_gender_female_V1.model.pt)
# Time elapsed: 35.86 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V1.model.pt
# Restart [20] - JSDs 0.121926599131718
# Finished training (checkpoint saved in: Sanger_gender_female_V1.model.pt)
# Time elapsed: 35.91 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V1.model.pt
# Restart [21] - JSDs 0.121926599131718
# Finished training (checkpoint saved in: Sanger_gender_female_V1.model.pt)
# Time elapsed: 35.88 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V1.model.pt
# Restart [22] - JSDs 0.121926599131718
# Finished training (checkpoint saved in: Sanger_gender_female_V1.model.pt)
# Time elapsed: 35.90 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V1.model.pt
# Restart [23] - JSDs 0.121926599131718
# Finished training (checkpoint saved in: Sanger_gender_female_V1.model.pt)
# Time elapsed: 35.90 (0.60 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V1.model.pt
# Restart [24] - JSDs 0.121926599131718
# Training experiment for dataset
# Finished training (checkpoint saved in: Sanger_gender_female_V2.model.pt)
# Time elapsed: 67.86 (1.13 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V2.model.pt
# Restart [0] - JSDs 0.15625370190267196
# Finished training (checkpoint saved in: Sanger_gender_female_V2.model.pt)
# Time elapsed: 43.48 (0.72 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V2.model.pt
# Restart [1] - JSDs 0.1534513745485162
# Finished training (checkpoint saved in: Sanger_gender_female_V2.model.pt)
# Time elapsed: 92.84 (1.55 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V2.model.pt
# Restart [2] - JSDs 0.14413444114855492
# Finished training (checkpoint saved in: Sanger_gender_female_V2.model.pt)
# Time elapsed: 37.21 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V2.model.pt
# Restart [3] - JSDs 0.14413444114855492
# Finished training (checkpoint saved in: Sanger_gender_female_V2.model.pt)
# Time elapsed: 37.19 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V2.model.pt
# Restart [4] - JSDs 0.14413444114855492
# Finished training (checkpoint saved in: Sanger_gender_female_V2.model.pt)
# Time elapsed: 37.22 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V2.model.pt
# Restart [5] - JSDs 0.14413444114855492
# Finished training (checkpoint saved in: Sanger_gender_female_V2.model.pt)
# Time elapsed: 37.21 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V2.model.pt
# Restart [6] - JSDs 0.14413444114855492
# Finished training (checkpoint saved in: Sanger_gender_female_V2.model.pt)
# Time elapsed: 49.87 (0.83 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V2.model.pt
# Restart [7] - JSDs 0.14035491504004313
# Finished training (checkpoint saved in: Sanger_gender_female_V2.model.pt)
# Time elapsed: 37.22 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V2.model.pt
# Restart [8] - JSDs 0.14035491504004313
# Finished training (checkpoint saved in: Sanger_gender_female_V2.model.pt)
# Time elapsed: 37.29 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V2.model.pt
# Restart [9] - JSDs 0.14035491504004313
# Finished training (checkpoint saved in: Sanger_gender_female_V2.model.pt)
# Time elapsed: 49.63 (0.83 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V2.model.pt
# Restart [10] - JSDs 0.13816153007215284
# Finished training (checkpoint saved in: Sanger_gender_female_V2.model.pt)
# Time elapsed: 37.23 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V2.model.pt
# Restart [11] - JSDs 0.13816153007215284
# Finished training (checkpoint saved in: Sanger_gender_female_V2.model.pt)
# Time elapsed: 67.75 (1.13 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V2.model.pt
# Restart [12] - JSDs 0.13806866715002056
# Finished training (checkpoint saved in: Sanger_gender_female_V2.model.pt)
# Time elapsed: 36.89 (0.61 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V2.model.pt
# Restart [13] - JSDs 0.13806866715002056
# Finished training (checkpoint saved in: Sanger_gender_female_V2.model.pt)
# Time elapsed: 37.05 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V2.model.pt
# Restart [14] - JSDs 0.13806866715002056
# Finished training (checkpoint saved in: Sanger_gender_female_V2.model.pt)
# Time elapsed: 36.88 (0.61 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V2.model.pt
# Restart [15] - JSDs 0.13806866715002056
# Finished training (checkpoint saved in: Sanger_gender_female_V2.model.pt)
# Time elapsed: 36.87 (0.61 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V2.model.pt
# Restart [16] - JSDs 0.13806866715002056
# Finished training (checkpoint saved in: Sanger_gender_female_V2.model.pt)
# Time elapsed: 36.88 (0.61 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V2.model.pt
# Restart [17] - JSDs 0.13806866715002056
# Finished training (checkpoint saved in: Sanger_gender_female_V2.model.pt)
# Time elapsed: 36.87 (0.61 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V2.model.pt
# Restart [18] - JSDs 0.13806866715002056
# Finished training (checkpoint saved in: Sanger_gender_female_V2.model.pt)
# Time elapsed: 36.87 (0.61 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V2.model.pt
# Restart [19] - JSDs 0.13806866715002056
# Finished training (checkpoint saved in: Sanger_gender_female_V2.model.pt)
# Time elapsed: 36.87 (0.61 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V2.model.pt
# Restart [20] - JSDs 0.13806866715002056
# Finished training (checkpoint saved in: Sanger_gender_female_V2.model.pt)
# Time elapsed: 36.99 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V2.model.pt
# Restart [21] - JSDs 0.13806866715002056
# Finished training (checkpoint saved in: Sanger_gender_female_V2.model.pt)
# Time elapsed: 37.03 (0.62 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V2.model.pt
# Restart [22] - JSDs 0.13806866715002056
# Finished training (checkpoint saved in: Sanger_gender_female_V2.model.pt)
# Time elapsed: 36.87 (0.61 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V2.model.pt
# Restart [23] - JSDs 0.13806866715002056
# Finished training (checkpoint saved in: Sanger_gender_female_V2.model.pt)
# Time elapsed: 36.88 (0.61 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: Sanger_gender_female_V2.model.pt
# Restart [24] - JSDs 0.13806866715002056

# %%
for dat, experiment in experiments.items():
    print(dat, "Test mean JSDs:", "{:2f}%".format(AS.getMeanJSD(experiment, "test")*100))
# Out:
# Harvard_gender_female_full Test mean JSDs: 10.627662%
# Harvard_gender_female_V1 Test mean JSDs: 9.920403%
# Harvard_gender_female_V2 Test mean JSDs: 9.255984%
# Sanger_gender_female_full Test mean JSDs: 12.768898%
# Sanger_gender_female_V1 Test mean JSDs: 16.391650%
# Sanger_gender_female_V2 Test mean JSDs: 14.407963%

# %%
# Export gene and cell type names as signature for reuse
for dat in datasets.keys():
    signature = (list(datasets[dat].var_names), list(experiments[dat].celltypes))
    with open(f"{dat}.signature.pickle", "wb") as f:
        pickle.dump(signature, f)
